# %% [markdown]
# # EXPLORATORY DATA ANALYSIS ON A DATASET
# ### Objective:
# The main goal of this assignment is to conduct a thorough exploratory analysis of the "cardiographic.csv" dataset to uncover insights, identify patterns, and understand the dataset's underlying structure. You will use statistical summaries, visualizations, and data manipulation techniques to explore the dataset comprehensively.
# ### Dataset:
# + LB - Likely stands for "Baseline Fetal Heart Rate (FHR)" which represents the average fetal heart rate over a period.
# + AC - Could represent "Accelerations" in the FHR. Accelerations are usually a sign of fetal well-being.
# + FM - May indicate "Fetal Movements" detected by the monitor.
# + UC - Likely denotes "Uterine Contractions", which can impact the FHR pattern.
# + DL - Could stand for "Decelerations Late" with respect to uterine contractions, which can be a sign of fetal distress.
# + DS - May represent "Decelerations Short" or decelerations of brief duration.
# + DP - Could indicate "Decelerations Prolonged", or long-lasting decelerations.
# + ASTV - Might refer to "Percentage of Time with Abnormal Short Term Variability" in the FHR.
# + MSTV - Likely stands for "Mean Value of Short Term Variability" in the FHR.
# + ALTV - Could represent "Percentage of Time with Abnormal Long Term Variability" in the FHR.
# + MLTV - Might indicate "Mean Value of Long Term Variability" in the FHR.

# %% [markdown]
# ### Tasks:
# ### 1.	Data Cleaning and Preparation:
# + Load the dataset into a DataFrame or equivalent data structure.
# + Handle missing values appropriately (e.g., imputation, deletion).
# + Identify and correct any inconsistencies in data types (e.g., numerical values stored as strings).
# + Detect and treat outliers if necessary.

# %% [markdown]
# ######  * Load the dataset into a DataFrame or equivalent data structure.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('Cardiotocographic.csv')
data.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
# Replace 1 with 'Yes' and 2 with 'No'
data['NSP'] = data['NSP'].replace({1: 'Yes', 2: 'No'})

# %%
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# ###### * Handle missing values appropriately (e.g., imputation, deletion).

# %%
# Handle missing values appropriately (e.g., imputation, deletion).
data.shape
# Out:
# (2126, 14)

# %%
data.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   object
# dtypes: float64(13), object(1)
# memory usage: 232.7+ KB

# %%
# since it has missing values
# Replace missing values with the mean (or median) for each numerical column
data['LB'].fillna(data['LB'].mean(), inplace=True)
data['DS'].fillna(data['DS'].mean(), inplace=True)
data['DP'].fillna(data['DP'].mean(), inplace=True)
data['MLTV'].fillna(data['MLTV'].mean(), inplace=True)
data['Width'].fillna(data['Width'].mean(), inplace=True)
data['Tendency'].fillna(data['Tendency'].mean(), inplace=True)
data = data.dropna(subset=['NSP'])

# %%
data.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2121    False
# 2122    False
# 2123    False
# 2124    False
# 2125    False
# Length: 2105, dtype: bool

# %% [markdown]
# ###### handeled the missing values & checked for duplicates , no duplicate values

# %% [markdown]
# ######  * Identify and correct any inconsistencies in data types (e.g., numerical values stored as strings).

# %%
# Identify and correct any inconsistencies in data types (e.g., numerical values stored as strings)
data.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP          object
# dtype: object

# %% [markdown]
# ###### There are no inconsistencies in the data types, as all columns are correctly set to `float64`.

# %% [markdown]
# ###### * Detect and treat outliers if necessary.

# %%
# Detect and treat outliers
sns.catplot(data=data, kind='box')
plt.figure(figsize= (15,6))
plt.show()

# %% [markdown]
# ###### 'LB', 'DP', 'ASTV', 'MSTV', 'ALTV', 'MLTV', 'Tendency'  has notable outliers

# %%
outlier_cols = ['LB', 'DP', 'ASTV', 'MSTV', 'ALTV', 'MLTV', 'Tendency']

def remove_outliers_iqr(data, columns):
    for col in columns:
        Q1 = data[col].quantile(0.25)  # 25th percentile
        Q3 = data[col].quantile(0.75)  # 75th percentile
        IQR = Q3 - Q1  # Interquartile range

        #  outlier boundaries
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Detect outliers
        outliers = data[(data[col] < lower_bound) | (data[col] > upper_bound)]
        print(f"Column: {col} - Outliers detected: {len(outliers)}")

        # Remove outliers
        data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]
    
    return data

# Apply outlier removal
df_cleaned = remove_outliers_iqr(data, outlier_cols)

# Save cleaned data (optional)
df_cleaned.to_csv('cleaned_data.csv', index=False)

# Show summary
print("Outliers removed. Cleaned data saved as 'cleaned_data.csv'.")
# Out:
# Column: LB - Outliers detected: 10
# Column: DP - Outliers detected: 283
# Column: ASTV - Outliers detected: 9
# Column: MSTV - Outliers detected: 87
# Column: ALTV - Outliers detected: 220
# Column: MLTV - Outliers detected: 49
# Column: Tendency - Outliers detected: 8
# Outliers removed. Cleaned data saved as 'cleaned_data.csv'.

# %%
# Load the cleaned dataset
df_cleaned = pd.read_csv('cleaned_data.csv')

# Columns where outliers were removed
outlier_cols = ['LB', 'DP', 'ASTV', 'MSTV', 'ALTV', 'MLTV', 'Tendency']

# Check if extreme values are still present
summary = df_cleaned[outlier_cols].describe()
print(summary)

# Check row count difference
original_df = pd.read_csv('Cardiotocographic.csv')  # Replace with the original file
print(f"Original Rows: {original_df.shape[0]}, Cleaned Rows: {df_cleaned.shape[0]}")
# Out:
#                 LB      DP         ASTV         MSTV         ALTV  \
# count  1439.000000  1439.0  1439.000000  1439.000000  1439.000000
# mean    132.866900     0.0    45.381601     1.218286     5.037899
# std       9.709601     0.0    15.833877     0.585502     8.819080
# min     106.000000     0.0    15.000000     0.200000    -1.043619
# 25%     125.000000     0.0    32.000000     0.800000     0.000000
# 50%     133.000000     0.0    45.000000     1.200000     0.000000
# 75%     140.000000     0.0    58.000000     1.600000     6.245731
# max     160.000000     0.0    86.000000     2.900000    35.000000
#
#               MLTV     Tendency
# count  1439.000000  1439.000000
# mean      8.311702     0.355079
# std       4.498127     0.599877
# min      -0.191511    -1.006614
# 25%       5.435739     0.000000
# 50%       8.100000     0.000000
# 75%      11.200000     1.000000
# max      20.500000     1.023635
# Original Rows: 2126, Cleaned Rows: 1439

# %% [markdown]
# ###### Your cleaned dataset has 1,439 rows after removing 687 entries, with `DP` entirely 0 and some negative values in `ALTV` and `Tendency`. Key metrics show high variance in `ASTV`, `ALTV`, and `MLTV`, suggesting potential outliers.

# %% [markdown]
# ### 2.	Statistical Summary:
# + Provide a statistical summary for each variable in the dataset, including measures of central tendency (mean, median) and dispersion (standard deviation, interquartile range).
# + Highlight any interesting findings from this summary.

# %% [markdown]
# ###### * Provide a statistical summary for each variable in the dataset, including measures of central tendency (mean, median) and dispersion (standard deviation, interquartile range).

# %%
# Statistical summary of the dataset
summary = df_cleaned.describe()
summary
# Out:
#                 LB           AC           FM           UC           DL  \
# count  1439.000000  1439.000000  1439.000000  1439.000000  1439.000000
# mean    132.866900     0.003807     0.004834     0.004465     0.001639
# std       9.709601     0.004484     0.055553     0.003252     0.003118
# min     106.000000    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     125.000000     0.000000     0.000000     0.002270     0.000000
# 50%     133.000000     0.002551     0.000000     0.004532     0.000000
# 75%     140.000000     0.006404     0.002016     0.006595     0.002674
# max     160.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS      DP         ASTV         MSTV         ALTV  \
# count  1439.000000  1439.0  1439.000000  1439.000000  1439.000000
# mean      0.000002     0.0    45.381601     1.218286     5.037899
# std       0.000143     0.0    15.833877     0.585502     8.819080
# ...

# %%
# Calculating the interquartile range 
IQR = summary.loc['75%'] - summary.loc['25%']
summary_with_IQR = summary.append(IQR.rename('IQR'))
print(summary_with_IQR)
# Out:
#                 LB           AC           FM           UC           DL  \
# count  1439.000000  1439.000000  1439.000000  1439.000000  1439.000000
# mean    132.866900     0.003807     0.004834     0.004465     0.001639
# std       9.709601     0.004484     0.055553     0.003252     0.003118
# min     106.000000    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     125.000000     0.000000     0.000000     0.002270     0.000000
# 50%     133.000000     0.002551     0.000000     0.004532     0.000000
# 75%     140.000000     0.006404     0.002016     0.006595     0.002674
# max     160.000000     0.038567     0.961268     0.030002     0.030769
# IQR      15.000000     0.006404     0.002016     0.004325     0.002674
#
#                 DS      DP         ASTV         MSTV         ALTV  \
# count  1439.000000  1439.0  1439.000000  1439.000000  1439.000000
# mean      0.000002     0.0    45.381601     1.218286     5.037899
# ...

# %% [markdown]
# ###### * Highlight any interesting findings from this summary.

# %% [markdown]
# 1. LB (Last Beat): Values range from 106 to 160, with most clustered between 125 and 140, indicating some variability.
# 2. AC (Accelerations): Mean close to zero, with a few higher values (max = 0.0385). Some negative values could be errors.
# 3. FM (Fetal Movement) & UC (Uterine Contractions): Both skewed towards zero, with very low values and occasional outliers.
# 4. ALTV (Amplitude of Long-Term Variability): Contains negative values, with significant outliers (max = 35).
# 5. MSTV (Mean Short-Term Variability): Values range from 0.2 to 2.9, with moderate variability.
# 6. Tendency: Mostly binary (0 or 1), with a few negative values that may be outliers.
# 7. NSP (Non-Stress Pattern): Most values between 1 and 2, with rare outliers.
# Overall, many variables show skewed distributions and potential outliers, especially in ALTV, FM, and Tendency

# %% [markdown]
# ### 3.	Data Visualization:
# + Create histograms or boxplots to visualize the distributions of various numerical variables.
# + Use bar charts or pie charts to display the frequency of categories for categorical variables.
# + Generate scatter plots or correlation heatmaps to explore relationships between pairs of variables.
# + Employ advanced visualization techniques like pair plots, or violin plots for deeper insights.

# %% [markdown]
# ###### * Creating histograms to visualize the distributions of various numerical variables.

# %%
# List of numerical columns
numerical_cols = ['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV', 'MLTV', 'Width', 'Tendency']

# Set up the figure
plt.figure(figsize=(15, 12))

# Create histograms for each numerical column
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(4, 4, i)  # Create a 4x4 grid of subplots
    sns.histplot(df_cleaned[col], kde=True, bins=30)  # Histograms with kernel density estimation
    plt.title(f'Histogram of {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ###### * Using bar charts or pie charts to display the frequency of categories for categorical variables.

# %%
df_cleaned.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP          object
# dtype: object

# %%
# Count the occurrences of each category
category_counts = df_cleaned['NSP'].value_counts()
# Pie Chart
plt.figure(figsize=(5, 5))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', colors=['b','r','g','y','c'])
plt.title('Pie Chart of NSP Categories')
plt.show()

# %% [markdown]
# ###### Here the dataset does not contain any categorical variables; all columns are of type `float64`, meaning they are numeric.

# %% [markdown]
# ###### * Generating correlation scatter plot to explore relationships between pairs of variables.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the cleaned dataset
df_cleaned = pd.read_csv('cleaned_data.csv')

# Select only numerical columns
numerical_df = df_cleaned.select_dtypes(include=['float64', 'int64'])

# Pairplot for all numerical columns
sns.pairplot(numerical_df, diag_kind='kde', markers='o', plot_kws={'alpha': 0.5})

# Show the plots
plt.show()

# %% [markdown]
# ###### * Employ advanced visualization techniques like pair plots for deeper insights.

# %%
cols = df_cleaned.select_dtypes(include=['float64', 'int64']).columns

for col in cols:
    plt.figure(figsize=(4,2))
    sns.violinplot(y=df_cleaned[col])  # Only the numerical column on the y-axis
    plt.title(f'Violin Plot of {col}')
    plt.show()

# %% [markdown]
# ### 4.	Pattern Recognition and Insights:
# + Identify any correlations between variables and discuss their potential implications.
# + Look for trends or patterns over time if temporal data is available.

# %% [markdown]
# ###### * Identify any correlations between variables and discuss their potential implications.

# %%
# To identify correlation b/w variables we generate correlation matrix
correlation_matrix = df_cleaned.corr()
# Plot the correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4788\3896671107.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_cleaned.corr()

# %% [markdown]
# + Highly Correlated Pairs:
# MSTV & Width (0.51): Strong positive correlation, meaning as MSTV increases, Width also tends to increase.
# DL & MSTV (0.47): Moderate correlation, indicating some influence between the variables.
#
# + Negative Correlations:
# MSTV & ASTV (-0.42): Strong inverse relationship; as MSTV increases, ASTV decreases.
# MSTV & ALTV (-0.45): Indicates opposite behavior between MSTV and ALTV.
#
# + Low or No Correlation:
# Many pairs have near-zero correlation, suggesting weak or no direct influence.

# %% [markdown]
# ###### * Look for trends or patterns over time if temporal data is available.

# %%
df_cleaned.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP          object
# dtype: object

# %% [markdown]
# ###### The dataset consists of numerical columns, but none of them represent time or date information, which is typically used for temporal data analysis. Temporal data usually involves variables like timestamps, dates, or time intervals, which are absent in this case.

# %% [markdown]
# ### 5.	Conclusion:
# + Summarize the key insights and patterns discovered through your exploratory analysis.
# + Discuss how these findings could impact decision-making or further analyses.

# %% [markdown]
# ###### * Summarize the key insights and patterns discovered through your exploratory analysis.
# Through my exploratory analysis, I identified key trends and patterns in the dataset, such as correlations between specific features and target outcomes. Missing values and outliers were detected, prompting data cleaning. I observed certain variables significantly impacting performance, which could guide future analysis. Visualizations highlighted relationships and helped in understanding the distribution and variability of key variables. This analysis has laid the groundwork for more detailed modeling and hypothesis testing.
#
#
# ###### *  Discuss how these findings could impact decision-making or further analyses.
# These findings can guide decision-making by identifying key variables that affect performance, helping target improvements. The detection of missing values and outliers highlights the need for data cleaning, enhancing model accuracy. Recognizing relationships between features helps focus future analyses and improve predictions. This also supports generating hypotheses for deeper insights.
